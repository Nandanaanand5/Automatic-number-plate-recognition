# %%
import os

# %%
import glob

# %%
from IPython.display import Image,display

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
HOME=os.getcwd()

# %%
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.2.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 3.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.8/78.2 GB disk)

# %%
# !mkdir {HOME}/datasets

# %%
# !pwd
# Out:
# /content

# %%
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pwd
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="PEePimj9kaB6ql34qjiJ")
project = rf.workspace("matheus-santos-almeida").project("car_license_plate")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.1/74.1 kB 980.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %%
# %cd {HOME}
# Out:
# /content

# %%
# %cd {dataset.location}
# Out:
# /content/datasets/car_license_plate-1

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/datasets/car_license_plate-1/data.yaml epochs=90 imgsz=640
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls /content/datasets/car_license_plate-1/runs/detect/train3
# Out:
# args.yaml					    PR_curve.png	 train_batch1.jpg
# confusion_matrix_normalized.png			    R_curve.png		 train_batch2.jpg
# confusion_matrix.png				    results.csv		 val_batch0_labels.jpg
# events.out.tfevents.1714111357.aeea52348b8b.2106.0  results.png		 val_batch0_pred.jpg
# F1_curve.png					    train_batch0.jpg	 val_batch1_labels.jpg
# labels_correlogram.jpg				    train_batch1120.jpg  val_batch1_pred.jpg
# labels.jpg					    train_batch1121.jpg  weights
# P_curve.png					    train_batch1122.jpg

# %%
# %cd {HOME}
# !yolo task=detect mode=val model=/content/datasets/car_license_plate-1/runs/detect/train3/weights/best.pt data=/content/datasets/car_license_plate-1/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/datasets/car_license_plate-1/valid/labels.cache... 60 images, 0 backgrounds, 0 corrupt: 100% 60/60 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:06<00:00,  1.53s/it]
#                    all         60         64      0.744      0.781      0.809       0.49
# Speed: 0.2ms preprocess, 35.2ms inference, 0.0ms loss, 42.5ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 61.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 37.6 MB/s eta 0:00:00
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=/content/datasets/car_license_plate-1/runs/detect/train3/weights/best.pt conf=0.25 source='/content/demo (1).mp4'
# Out:
# /content
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (frame 1/631) /content/demo (1).mp4: 416x640 2 licences, 103.7ms
# video 1/1 (frame 2/631) /content/demo (1).mp4: 416x640 2 licences, 27.0ms
# video 1/1 (frame 3/631) /content/demo (1).mp4: 416x640 2 licences, 26.9ms
# video 1/1 (frame 4/631) /content/demo (1).mp4: 416x640 3 licences, 26.8ms
# video 1/1 (frame 5/631) /content/demo (1).mp4: 416x640 2 licences, 26.1ms
# video 1/1 (frame 6/631) /content/demo (1).mp4: 416x640 2 licences, 25.7ms
# video 1/1 (frame 7/631) /content/demo (1).mp4: 416x640 2 licences, 25.7ms
# video 1/1 (frame 8/631) /content/demo (1).mp4: 416x640 2 licences, 25.7ms
# video 1/1 (frame 9/631) /content/demo (1).mp4: 416x640 3 licences, 25.7ms
# video 1/1 (frame 10/631) /content/demo (1).mp4: 416x640 2 licences, 17.6ms
# ...

# %%
# !pip install ultralytics
# !python /content/datasets/car_license_plate-1/runs/detect/train3/predictWithOCR.py--model '/content/datasets/car_license_plate-1/runs/detect/train3/weights/best.pt' --source '/content/demo (1).mp4'
# Out:
# ...
# python3: can't open file '/content/datasets/car_license_plate-1/runs/detect/train3/predictWithOCR.py--model': [Errno 2] No such file or directory
